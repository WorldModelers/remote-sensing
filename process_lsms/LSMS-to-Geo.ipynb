# %% [markdown]
# # LSMS Processing

# %%
import pandas as pd

# %%
year = 2011

if year == 2015:
    LSMS_PATH = '/Users/brandon/Downloads/ETH_2015_ESS_v02_M_STATA8'
elif year == 2013:
    LSMS_PATH = '/Users/brandon/Downloads/ETH_2013_ESS_v02_M_Stata8'
elif year == 2011:
    LSMS_PATH = '/Users/brandon/Downloads/ETH_2011_ERSS_v02_M_Stata8'

# %% [markdown]
# ## Load Crop Yield Data

# %%
vars_ = pd.read_csv('Harvest_by_Field_data_dict.csv').set_index('Variable')

# %%
vars_dict = vars_.to_dict()

# %%
if year in [2013, 2015]:
    vars_to_select = ['household_id2','saq01','saq02','saq03','saq04','parcel_id','field_id','crop_name','ph_s9q04_a','ph_s9q04_b']

# 2011 did not have non-standardized (kg, g) units, so we should just use the kg variable    
elif year == 2011:
    vars_to_select = ['household_id2','saq01','saq02','saq03','saq04','parcel_id','field_id','crop_name','ph_s9q12_a']

# %%
if year == 2015:
    int_path = "Post-Harvest/"
    wave = 3
elif year == 2013:
    int_path = ""
    wave = 2
elif year == 2011:
    int_path = ""
    wave = 1
    
c_yields = pd.read_stata(f'{LSMS_PATH}/{int_path}sect9_ph_w{wave}.dta')

if year == 2013:
    c_yields['crop_name'] = c_yields['crop_code']
    
if year == 2011:
    c_yields['household_id2'] = c_yields['household_id']

# %%
c_yields = c_yields[vars_to_select]

# %%
c_yields = c_yields.rename(columns=vars_dict['Definition'])

# %%
c_yields = c_yields.set_index('Unique HH ID in wave 2')

# %% [markdown]
# Remove NA values from dataset (household missing)

# %%
c_yields = c_yields.dropna()

# %%
num_hh = c_yields.reset_index().groupby('Unique HH ID in wave 2')['Field ID'].count().shape[0]
num_fields = sum(c_yields.reset_index().groupby('Unique HH ID in wave 2')['Field ID'].count())

# %%
print(f"There are {num_hh} households with {num_fields} total fields.")
# Out:
# There are 1612 households with 4052 total fields.

# %% [markdown]
# ## Load Field Area information

# %%
if year == 2015:
    int_path = "Post-Planting/"
    wave = 3
    path = "sect_3"
elif year == 2013:
    int_path = ""
    wave = 2
    path = "sect_3"    
elif year == 2011:
    int_path = ""
    wave = 1
    path = "sect3_"

# %%
c_area = pd.read_stata(f'{LSMS_PATH}/{int_path}{path}rca_pp_w{wave}.dta')

# %%
if year in [2013, 2015]:
    area_vars = ['household_id2','parcel_id','field_id','pp_rcq02_a','pp_rcq02_b']

# 2011 did not have non-standardized (kg, g) units, so we should just use the kg variable    
elif year == 2011:
    area_vars = ['household_id','parcel_id','field_id','pp_rcq02_a','pp_rcq02_b']

# %%
c_area = c_area[area_vars].dropna(subset=['pp_rcq02_a'])

if year == 2011:
    c_area['household_id2'] = c_area['household_id']
    del(c_area['household_id'])

# %%
print(f"{c_area.shape[0]} total fields have area information")
# Out:
# 5031 total fields have area information

# %%
new_vars = {'parcel_id': 'Parcel ID', 'field_id': 'Field ID', 'pp_rcq02_a': 'Area', 'pp_rcq02_b': 'Area (decimal)'}
c_area = c_area.rename(columns=new_vars)

# %%
new_df = pd.merge(c_yields.reset_index(), c_area, 
                  how='left', 
                  left_on=['Unique HH ID in wave 2','Parcel ID','Field ID'], 
                  right_on = ['household_id2','Parcel ID','Field ID'])

# %%
c_yields = new_df.set_index('Unique HH ID in wave 2')

# %% [markdown]
# ## Load Geo Houshould information

# %%
if year == 2015:
    int_path = "Geovariables/"
    f = "ETH_HouseholdGeovars_y3.dta"
elif year == 2013:
    int_path = ""
    f = "Pub_ETH_HouseholdGeovars_Y2.dta"
elif year == 2011:
    int_path = ""
    f = "Pub_ETH_HouseholdGeovariables_Y1.dta"    
    
household_geo = pd.read_stata(f'{LSMS_PATH}/{int_path}{f}')

# %%
if year in [2013, 2015]:
    household_vars = {
    'household_id2':'Unique HH ID in wave 2',
    'lon_dd_mod':'EA Longitude (WGS84) Modified',
    'lat_dd_mod':'EA Latitude (WGS84) Modified'
    }
elif year == 2011:
    household_vars = {
    'household_id':'Unique HH ID in wave 2',
    'LAT_DD_MOD':'EA Latitude (WGS84) Modified',
    'LON_DD_MOD':'EA Longitude (WGS84) Modified'
    }

# %%
household_geo = household_geo[household_vars.keys()].rename(columns=household_vars)

# %% [markdown]
# Add this geospatial data to crop yield information

# %%
c_yields = c_yields.join(household_geo.set_index('Unique HH ID in wave 2'), on='Unique HH ID in wave 2', how='left')

# %%
c_yields
# Out:
#                        Region Code  Zone Code  Woreda Code  Kebele/FA Code  \
# Unique HH ID in wave 2
# 01010101601002              Tigray          1            1              16
# 01010101601002              Tigray          1            1              16
# 01010101601002              Tigray          1            1              16
# 01010101601017              Tigray          1            1              16
# 01010101601017              Tigray          1            1              16
# 01010101601101              Tigray          1            1              16
# 01010101601101              Tigray          1            1              16
# 01010101601101              Tigray          1            1              16
# 01010101601116              Tigray          1            1              16
# 01010101601116              Tigray          1            1              16
# 01010101601146              Tigray          1            1              16
# 01010201403001              Tigray          1            2              14
# 01010201403001              Tigray          1            2              14
# 01010201403011              Tigray          1            2              14
# 01010201403016              Tigray          1            2              14
# 01010201403026              Tigray          1            2              14
# 01010201403046              Tigray          1            2              14
# 01010201403046              Tigray          1            2              14
# 01010201403046              Tigray          1            2              14
# 01010201403061              Tigray          1            2              14
# 01010201403061              Tigray          1            2              14
# 01010201403061              Tigray          1            2              14
# 01010201403106              Tigray          1            2              14
# 01010300106052              Tigray          1            3               1
# 01010300106136              Tigray          1            3               1
# 01010301804004              Tigray          1            3              18
# 01010301804004              Tigray          1            3              18
# 01010301804019              Tigray          1            3              18
# 01010301804034              Tigray          1            3              18
# 01010301804034              Tigray          1            3              18
# ...                            ...        ...          ...             ...
# 15010201605132           Dire Dawa          1            2              16
# 15010201805001           Dire Dawa          1            2              18
# 15010201805011           Dire Dawa          1            2              18
# 15010201805011           Dire Dawa          1            2              18
# 15010201805016           Dire Dawa          1            2              18
# 15010201805016           Dire Dawa          1            2              18
# 15010201805016           Dire Dawa          1            2              18
# 15010201805026           Dire Dawa          1            2              18
# 15010201805031           Dire Dawa          1            2              18
# 15010201805046           Dire Dawa          1            2              18
# 15010201805061           Dire Dawa          1            2              18
# 15010201805121           Dire Dawa          1            2              18
# 15010202404016           Dire Dawa          1            2              24
# 15010202404040           Dire Dawa          1            2              24
# 15010202404052           Dire Dawa          1            2              24
# 15010202404052           Dire Dawa          1            2              24
# 15010202404052           Dire Dawa          1            2              24
# 15010202404076           Dire Dawa          1            2              24
# 15010202404076           Dire Dawa          1            2              24
# 15010202404076           Dire Dawa          1            2              24
# 15010202404076           Dire Dawa          1            2              24
# 15010202404076           Dire Dawa          1            2              24
# 15010202404112           Dire Dawa          1            2              24
# 15010202801019           Dire Dawa          1            2              28
# 15010202801049           Dire Dawa          1            2              28
# 15010202801112           Dire Dawa          1            2              28
# 15010202801127           Dire Dawa          1            2              28
# 15010203102022           Dire Dawa          1            2              31
# 15010203102044           Dire Dawa          1            2              31
# 15010203102087           Dire Dawa          1            2              31
#
#                         Parcel ID  Field ID      Crop Name  \
# Unique HH ID in wave 2
# 01010101601002                  1         4        SORGHUM
# 01010101601002                  1         2         MILLET
# 01010101601002                  1         2         MILLET
# 01010101601017                  2         1         MILLET
# 01010101601017                  3         1        SORGHUM
# 01010101601101                  1         5         MILLET
# 01010101601101                  1         7         SESAME
# 01010101601101                  1        10         MILLET
# 01010101601116                  1         2          MAIZE
# 01010101601116                  4         1         SESAME
# 01010101601146                  1         2          MAIZE
# 01010201403001                  1         4           TEFF
# 01010201403001                  9         1         MILLET
# 01010201403011                  1         7       LINESEED
# 01010201403016                  1         2          MAIZE
# 01010201403026                  1         4           TEFF
# 01010201403046                  1         5         BARLEY
# 01010201403046                  1         6          MAIZE
# 01010201403046                  8         1           TEFF
# 01010201403061                  1         4         BARLEY
# 01010201403061                  1         6         BARLEY
# 01010201403061                  6         3    HORSE BEANS
# 01010201403106                  2         1           TEFF
# 01010300106052                  1         2          MAIZE
# 01010300106136                  1         2          MAIZE
# 01010301804004                  1         7          MAIZE
# 01010301804004                  1         9           TEFF
# 01010301804019                  2         1           TEFF
# 01010301804034                  1         4  HARICOT BEANS
# 01010301804034                  2         1           TEFF
# ...                           ...       ...            ...
# 15010201605132                  4         4
# 15010201805001                  1        11
# 15010201805011                  2         6
# 15010201805011                  2        10
# 15010201805016                  1         1
# 15010201805016                  1         2
# 15010201805016                  2         1
# 15010201805026                  3         3
# 15010201805031                  1         3
# 15010201805046                  2         7
# 15010201805061                  1         8
# 15010201805121                  1         2
# 15010202404016                  3         2
# 15010202404040                  3         9
# 15010202404052                  2         5
# 15010202404052                  2         6
# 15010202404052                  2         9
# 15010202404076                  1         1
# 15010202404076                  2         2
# 15010202404076                  2         3
# 15010202404076                  2         4
# 15010202404076                  2         5
# 15010202404112                  4         4
# 15010202801019                  2         6
# 15010202801049                  2         4
# 15010202801112                  2         1
# 15010202801127                  4         1
# 15010203102022                  1         1
# 15010203102044                  1         2
# 15010203102087                  2         1
#
#                         How much crop harvested from this field during the last season KILOS  \
# Unique HH ID in wave 2
# 01010101601002                                                      600.0
# 01010101601002                                                      200.0
# 01010101601002                                                      200.0
# 01010101601017                                                       80.0
# 01010101601017                                                      600.0
# 01010101601101                                                      100.0
# 01010101601101                                                      100.0
# 01010101601101                                                      200.0
# 01010101601116                                                        8.0
# 01010101601116                                                      200.0
# 01010101601146                                                       10.0
# 01010201403001                                                      170.0
# 01010201403001                                                      260.0
# 01010201403011                                                        8.0
# 01010201403016                                                      200.0
# 01010201403026                                                       70.0
# 01010201403046                                                       10.0
# 01010201403046                                                      250.0
# 01010201403046                                                      200.0
# 01010201403061                                                       30.0
# 01010201403061                                                       24.0
# 01010201403061                                                       10.0
# 01010201403106                                                      100.0
# 01010300106052                                                        2.0
# 01010300106136                                                        7.0
# 01010301804004                                                       25.0
# 01010301804004                                                       17.0
# 01010301804019                                                      120.0
# 01010301804034                                                       30.0
# 01010301804034                                                      100.0
# ...                                                                   ...
# 15010201605132                                                        5.0
# 15010201805001                                                       40.0
# 15010201805011                                                       18.0
# 15010201805011                                                        0.0
# 15010201805016                                                      132.0
# 15010201805016                                                       22.0
# 15010201805016                                                       93.0
# 15010201805026                                                       56.0
# 15010201805031                                                       24.0
# 15010201805046                                                       22.0
# 15010201805061                                                       40.0
# 15010201805121                                                       20.0
# 15010202404016                                                       25.0
# 15010202404040                                                       25.0
# 15010202404052                                                        1.0
# 15010202404052                                                        0.0
# 15010202404052                                                        0.0
# 15010202404076                                                       50.0
# 15010202404076                                                        9.0
# 15010202404076                                                       19.0
# 15010202404076                                                       28.0
# 15010202404076                                                       11.0
# 15010202404112                                                       19.0
# 15010202801019                                                       40.0
# 15010202801049                                                       25.0
# 15010202801112                                                       40.0
# 15010202801127                                                      400.0
# 15010203102022                                                      400.0
# 15010203102044                                                        0.0
# 15010203102087                                                       40.0
#
#                           Area  Area (decimal)   household_id2  \
# Unique HH ID in wave 2
# 01010101601002          5946.0            89.0  01010101601002
# 01010101601002            69.0            99.0  01010101601002
# 01010101601002          7751.0            70.0  01010101601002
# 01010101601017          1525.0            16.0  01010101601017
# 01010101601017          6532.0            52.0  01010101601017
# 01010101601101          1594.0            47.0  01010101601101
# 01010101601101           371.0            23.0  01010101601101
# 01010101601101          4724.0            86.0  01010101601101
# 01010101601116           115.0            12.0  01010101601116
# 01010101601116          3203.0             1.0  01010101601116
# 01010101601146           245.0            77.0  01010101601146
# 01010201403001          1412.0            24.0  01010201403001
# 01010201403001          5136.0            23.0  01010201403001
# 01010201403011           119.0            81.0  01010201403011
# 01010201403016          4584.0            99.0  01010201403016
# 01010201403026           777.0            17.0  01010201403026
# 01010201403046            83.0            30.0  01010201403046
# 01010201403046          4879.0            24.0  01010201403046
# 01010201403046          5319.0             8.0  01010201403046
# 01010201403061            84.0            57.0  01010201403061
# 01010201403061           118.0            63.0  01010201403061
# 01010201403061           120.0            58.0  01010201403061
# 01010201403106          1964.0            89.0  01010201403106
# 01010300106052            50.0            72.0  01010300106052
# 01010300106136           185.0            78.0  01010300106136
# 01010301804004           279.0            91.0  01010301804004
# 01010301804004           276.0            53.0  01010301804004
# 01010301804019          2213.0            95.0  01010301804019
# 01010301804034           187.0            58.0  01010301804034
# 01010301804034          1663.0            61.0  01010301804034
# ...                        ...             ...             ...
# 15010201605132             NaN             NaN             NaN
# 15010201805001             NaN             NaN             NaN
# 15010201805011             NaN             NaN             NaN
# 15010201805011             NaN             NaN             NaN
# 15010201805016             NaN             NaN             NaN
# 15010201805016             NaN             NaN             NaN
# 15010201805016             NaN             NaN             NaN
# 15010201805026             NaN             NaN             NaN
# 15010201805031             NaN             NaN             NaN
# 15010201805046             NaN             NaN             NaN
# 15010201805061             NaN             NaN             NaN
# 15010201805121             NaN             NaN             NaN
# 15010202404016             NaN             NaN             NaN
# 15010202404040             NaN             NaN             NaN
# 15010202404052             NaN             NaN             NaN
# 15010202404052             NaN             NaN             NaN
# 15010202404052             NaN             NaN             NaN
# 15010202404076             NaN             NaN             NaN
# 15010202404076             NaN             NaN             NaN
# 15010202404076             NaN             NaN             NaN
# 15010202404076             NaN             NaN             NaN
# 15010202404076             NaN             NaN             NaN
# 15010202404112             NaN             NaN             NaN
# 15010202801019             NaN             NaN             NaN
# 15010202801049             NaN             NaN             NaN
# 15010202801112             NaN             NaN             NaN
# 15010202801127             NaN             NaN             NaN
# 15010203102022             NaN             NaN             NaN
# 15010203102044             NaN             NaN             NaN
# 15010203102087             NaN             NaN             NaN
#
#                         EA Latitude (WGS84) Modified  \
# Unique HH ID in wave 2
# 01010101601002                             14.353816
# 01010101601002                             14.353816
# 01010101601002                             14.353816
# 01010101601017                             14.353816
# 01010101601017                             14.353816
# 01010101601101                             14.353816
# 01010101601101                             14.353816
# 01010101601101                             14.353816
# 01010101601116                             14.353816
# 01010101601116                             14.353816
# 01010101601146                             14.353816
# 01010201403001                             14.288590
# 01010201403001                             14.288590
# 01010201403011                             14.288590
# 01010201403016                             14.288590
# 01010201403026                             14.288590
# 01010201403046                             14.288590
# 01010201403046                             14.288590
# 01010201403046                             14.288590
# 01010201403061                             14.288590
# 01010201403061                             14.288590
# 01010201403061                             14.288590
# 01010201403106                             14.288590
# 01010300106052                             14.109761
# 01010300106136                             14.109761
# 01010301804004                             13.844084
# 01010301804004                             13.844084
# 01010301804019                             13.844084
# 01010301804034                             13.844084
# 01010301804034                             13.844084
# ...                                              ...
# 15010201605132                              9.550917
# 15010201805001                              9.567890
# 15010201805011                              9.567890
# 15010201805011                              9.567890
# 15010201805016                              9.567890
# 15010201805016                              9.567890
# 15010201805016                              9.567890
# 15010201805026                              9.567890
# 15010201805031                              9.567890
# 15010201805046                              9.567890
# 15010201805061                              9.567890
# 15010201805121                              9.567890
# 15010202404016                              9.602981
# 15010202404040                              9.602981
# 15010202404052                              9.602981
# 15010202404052                              9.602981
# 15010202404052                              9.602981
# 15010202404076                              9.602981
# 15010202404076                              9.602981
# 15010202404076                              9.602981
# 15010202404076                              9.602981
# 15010202404076                              9.602981
# 15010202404112                              9.602981
# 15010202801019                              9.630952
# 15010202801049                              9.630952
# 15010202801112                              9.630952
# 15010202801127                              9.630952
# 15010203102022                              9.746772
# 15010203102044                              9.746772
# 15010203102087                              9.746772
#
#                         EA Longitude (WGS84) Modified
# Unique HH ID in wave 2
# 01010101601002                              37.890876
# 01010101601002                              37.890876
# 01010101601002                              37.890876
# 01010101601017                              37.890876
# 01010101601017                              37.890876
# 01010101601101                              37.890876
# 01010101601101                              37.890876
# 01010101601101                              37.890876
# 01010101601116                              37.890876
# 01010101601116                              37.890876
# 01010101601146                              37.890876
# 01010201403001                              38.210252
# 01010201403001                              38.210252
# 01010201403011                              38.210252
# 01010201403016                              38.210252
# 01010201403026                              38.210252
# 01010201403046                              38.210252
# 01010201403046                              38.210252
# 01010201403046                              38.210252
# 01010201403061                              38.210252
# 01010201403061                              38.210252
# 01010201403061                              38.210252
# 01010201403106                              38.210252
# 01010300106052                              38.473835
# 01010300106136                              38.473835
# 01010301804004                              38.480325
# 01010301804004                              38.480325
# 01010301804019                              38.480325
# 01010301804034                              38.480325
# 01010301804034                              38.480325
# ...                                               ...
# 15010201605132                              42.082365
# 15010201805001                              41.982267
# 15010201805011                              41.982267
# 15010201805011                              41.982267
# 15010201805016                              41.982267
# 15010201805016                              41.982267
# 15010201805016                              41.982267
# 15010201805026                              41.982267
# 15010201805031                              41.982267
# 15010201805046                              41.982267
# 15010201805061                              41.982267
# 15010201805121                              41.982267
# 15010202404016                              42.080329
# 15010202404040                              42.080329
# 15010202404052                              42.080329
# 15010202404052                              42.080329
# 15010202404052                              42.080329
# 15010202404076                              42.080329
# 15010202404076                              42.080329
# 15010202404076                              42.080329
# 15010202404076                              42.080329
# 15010202404076                              42.080329
# 15010202404112                              42.080329
# 15010202801019                              42.146105
# 15010202801049                              42.146105
# 15010202801112                              42.146105
# 15010202801127                              42.146105
# 15010203102022                              42.308967
# 15010203102044                              42.308967
# 15010203102087                              42.308967
#
# [4060 rows x 13 columns]

# %%
c_yields = c_yields.reset_index()

# %%
c_yields.shape
# Out:
# (4060, 14)

# %% [markdown]
# ### Crop Unit Conversions

# %%
if year == 2015:
    int_path = "Food and Crop Conversion Factors/"
    f = "Crop_CF_Wave3.dta"
elif year == 2013:
    int_path = ""
    f = "Crop_CF_Wave2.dta"
elif year == 2011:
    int_path = ""
    f = "Food_CF_Wave1.dta"    

c_conversions = pd.read_stata(f'{LSMS_PATH}/{int_path}{f}')

# %%
if year in [2013, 2015]:
    c_conversions_vars = {'crop_code': 'Crop Name', 'unit_cd': 'Unit Code', 'mean_cf_nat': 'Conversion Factor (National)'}
elif year == 2011:
    c_conversions_vars = {'item_cd': 'Crop Name', 'unit_cd': 'Unit Code', 'mean_cf_nat': 'Conversion Factor (National)'}
    
c_conversions = c_conversions[c_conversions_vars.keys()]
c_conversions = c_conversions.rename(columns=c_conversions_vars)

# %%
if year == 2015:
    c_conversions['Crop Name'] = c_conversions['Crop Name'].apply(lambda x: x.split('. ')[1])
    c_conversions['Unit Code'] = c_conversions['Unit Code'].apply(lambda x: x.split('. ')[1])

# %%
c_conversions = c_conversions.drop_duplicates(subset=['Crop Name','Unit Code'])

# %% [markdown]
# Add conversion factor to yields dataframe:

# %%
if year in [2013, 2015]:
    c_yields = pd.merge(c_yields,
                    c_conversions,
                    how='left',
                    left_on=['Crop Name','How much [CROP] did you harvest from this [FIELD](UNIT)'],
                    right_on=['Crop Name','Unit Code'])

# %% [markdown]
# Perform conversion:

# %%
if year in [2013, 2015]:
    c_yields['Quantity_Kilograms'] = c_yields['How much [CROP] did you harvest from this [FIELD](QUANTITY)'] * c_yields['Conversion Factor (National)']
elif year == 2011:
    c_yields['Quantity_Kilograms'] = c_yields['How much crop harvested from this field during the last season KILOS']

# %%
c_yields
# Out:
#      Unique HH ID in wave 2 Region Code  Zone Code  Woreda Code  \
# 0            01010101601002      Tigray          1            1
# 1            01010101601002      Tigray          1            1
# 2            01010101601002      Tigray          1            1
# 3            01010101601017      Tigray          1            1
# 4            01010101601017      Tigray          1            1
# 5            01010101601101      Tigray          1            1
# 6            01010101601101      Tigray          1            1
# 7            01010101601101      Tigray          1            1
# 8            01010101601116      Tigray          1            1
# 9            01010101601116      Tigray          1            1
# 10           01010101601146      Tigray          1            1
# 11           01010201403001      Tigray          1            2
# 12           01010201403001      Tigray          1            2
# 13           01010201403011      Tigray          1            2
# 14           01010201403016      Tigray          1            2
# 15           01010201403026      Tigray          1            2
# 16           01010201403046      Tigray          1            2
# 17           01010201403046      Tigray          1            2
# 18           01010201403046      Tigray          1            2
# 19           01010201403061      Tigray          1            2
# 20           01010201403061      Tigray          1            2
# 21           01010201403061      Tigray          1            2
# 22           01010201403106      Tigray          1            2
# 23           01010300106052      Tigray          1            3
# 24           01010300106136      Tigray          1            3
# 25           01010301804004      Tigray          1            3
# 26           01010301804004      Tigray          1            3
# 27           01010301804019      Tigray          1            3
# 28           01010301804034      Tigray          1            3
# 29           01010301804034      Tigray          1            3
# ...                     ...         ...        ...          ...
# 4030         15010201605132   Dire Dawa          1            2
# 4031         15010201805001   Dire Dawa          1            2
# 4032         15010201805011   Dire Dawa          1            2
# 4033         15010201805011   Dire Dawa          1            2
# 4034         15010201805016   Dire Dawa          1            2
# 4035         15010201805016   Dire Dawa          1            2
# 4036         15010201805016   Dire Dawa          1            2
# 4037         15010201805026   Dire Dawa          1            2
# 4038         15010201805031   Dire Dawa          1            2
# 4039         15010201805046   Dire Dawa          1            2
# 4040         15010201805061   Dire Dawa          1            2
# 4041         15010201805121   Dire Dawa          1            2
# 4042         15010202404016   Dire Dawa          1            2
# 4043         15010202404040   Dire Dawa          1            2
# 4044         15010202404052   Dire Dawa          1            2
# 4045         15010202404052   Dire Dawa          1            2
# 4046         15010202404052   Dire Dawa          1            2
# 4047         15010202404076   Dire Dawa          1            2
# 4048         15010202404076   Dire Dawa          1            2
# 4049         15010202404076   Dire Dawa          1            2
# 4050         15010202404076   Dire Dawa          1            2
# 4051         15010202404076   Dire Dawa          1            2
# 4052         15010202404112   Dire Dawa          1            2
# 4053         15010202801019   Dire Dawa          1            2
# 4054         15010202801049   Dire Dawa          1            2
# 4055         15010202801112   Dire Dawa          1            2
# 4056         15010202801127   Dire Dawa          1            2
# 4057         15010203102022   Dire Dawa          1            2
# 4058         15010203102044   Dire Dawa          1            2
# 4059         15010203102087   Dire Dawa          1            2
#
#       Kebele/FA Code  Parcel ID  Field ID      Crop Name  \
# 0                 16          1         4        SORGHUM
# 1                 16          1         2         MILLET
# 2                 16          1         2         MILLET
# 3                 16          2         1         MILLET
# 4                 16          3         1        SORGHUM
# 5                 16          1         5         MILLET
# 6                 16          1         7         SESAME
# 7                 16          1        10         MILLET
# 8                 16          1         2          MAIZE
# 9                 16          4         1         SESAME
# 10                16          1         2          MAIZE
# 11                14          1         4           TEFF
# 12                14          9         1         MILLET
# 13                14          1         7       LINESEED
# 14                14          1         2          MAIZE
# 15                14          1         4           TEFF
# 16                14          1         5         BARLEY
# 17                14          1         6          MAIZE
# 18                14          8         1           TEFF
# 19                14          1         4         BARLEY
# 20                14          1         6         BARLEY
# 21                14          6         3    HORSE BEANS
# 22                14          2         1           TEFF
# 23                 1          1         2          MAIZE
# 24                 1          1         2          MAIZE
# 25                18          1         7          MAIZE
# 26                18          1         9           TEFF
# 27                18          2         1           TEFF
# 28                18          1         4  HARICOT BEANS
# 29                18          2         1           TEFF
# ...              ...        ...       ...            ...
# 4030              16          4         4
# 4031              18          1        11
# 4032              18          2         6
# 4033              18          2        10
# 4034              18          1         1
# 4035              18          1         2
# 4036              18          2         1
# 4037              18          3         3
# 4038              18          1         3
# 4039              18          2         7
# 4040              18          1         8
# 4041              18          1         2
# 4042              24          3         2
# 4043              24          3         9
# 4044              24          2         5
# 4045              24          2         6
# 4046              24          2         9
# 4047              24          1         1
# 4048              24          2         2
# 4049              24          2         3
# 4050              24          2         4
# 4051              24          2         5
# 4052              24          4         4
# 4053              28          2         6
# 4054              28          2         4
# 4055              28          2         1
# 4056              28          4         1
# 4057              31          1         1
# 4058              31          1         2
# 4059              31          2         1
#
#       How much crop harvested from this field during the last season KILOS  \
# 0                                                 600.0
# 1                                                 200.0
# 2                                                 200.0
# 3                                                  80.0
# 4                                                 600.0
# 5                                                 100.0
# 6                                                 100.0
# 7                                                 200.0
# 8                                                   8.0
# 9                                                 200.0
# 10                                                 10.0
# 11                                                170.0
# 12                                                260.0
# 13                                                  8.0
# 14                                                200.0
# 15                                                 70.0
# 16                                                 10.0
# 17                                                250.0
# 18                                                200.0
# 19                                                 30.0
# 20                                                 24.0
# 21                                                 10.0
# 22                                                100.0
# 23                                                  2.0
# 24                                                  7.0
# 25                                                 25.0
# 26                                                 17.0
# 27                                                120.0
# 28                                                 30.0
# 29                                                100.0
# ...                                                 ...
# 4030                                                5.0
# 4031                                               40.0
# 4032                                               18.0
# 4033                                                0.0
# 4034                                              132.0
# 4035                                               22.0
# 4036                                               93.0
# 4037                                               56.0
# 4038                                               24.0
# 4039                                               22.0
# 4040                                               40.0
# 4041                                               20.0
# 4042                                               25.0
# 4043                                               25.0
# 4044                                                1.0
# 4045                                                0.0
# 4046                                                0.0
# 4047                                               50.0
# 4048                                                9.0
# 4049                                               19.0
# 4050                                               28.0
# 4051                                               11.0
# 4052                                               19.0
# 4053                                               40.0
# 4054                                               25.0
# 4055                                               40.0
# 4056                                              400.0
# 4057                                              400.0
# 4058                                                0.0
# 4059                                               40.0
#
#         Area  Area (decimal)   household_id2  EA Latitude (WGS84) Modified  \
# 0     5946.0            89.0  01010101601002                     14.353816
# 1       69.0            99.0  01010101601002                     14.353816
# 2     7751.0            70.0  01010101601002                     14.353816
# 3     1525.0            16.0  01010101601017                     14.353816
# 4     6532.0            52.0  01010101601017                     14.353816
# 5     1594.0            47.0  01010101601101                     14.353816
# 6      371.0            23.0  01010101601101                     14.353816
# 7     4724.0            86.0  01010101601101                     14.353816
# 8      115.0            12.0  01010101601116                     14.353816
# 9     3203.0             1.0  01010101601116                     14.353816
# 10     245.0            77.0  01010101601146                     14.353816
# 11    1412.0            24.0  01010201403001                     14.288590
# 12    5136.0            23.0  01010201403001                     14.288590
# 13     119.0            81.0  01010201403011                     14.288590
# 14    4584.0            99.0  01010201403016                     14.288590
# 15     777.0            17.0  01010201403026                     14.288590
# 16      83.0            30.0  01010201403046                     14.288590
# 17    4879.0            24.0  01010201403046                     14.288590
# 18    5319.0             8.0  01010201403046                     14.288590
# 19      84.0            57.0  01010201403061                     14.288590
# 20     118.0            63.0  01010201403061                     14.288590
# 21     120.0            58.0  01010201403061                     14.288590
# 22    1964.0            89.0  01010201403106                     14.288590
# 23      50.0            72.0  01010300106052                     14.109761
# 24     185.0            78.0  01010300106136                     14.109761
# 25     279.0            91.0  01010301804004                     13.844084
# 26     276.0            53.0  01010301804004                     13.844084
# 27    2213.0            95.0  01010301804019                     13.844084
# 28     187.0            58.0  01010301804034                     13.844084
# 29    1663.0            61.0  01010301804034                     13.844084
# ...      ...             ...             ...                           ...
# 4030     NaN             NaN             NaN                      9.550917
# 4031     NaN             NaN             NaN                      9.567890
# 4032     NaN             NaN             NaN                      9.567890
# 4033     NaN             NaN             NaN                      9.567890
# 4034     NaN             NaN             NaN                      9.567890
# 4035     NaN             NaN             NaN                      9.567890
# 4036     NaN             NaN             NaN                      9.567890
# 4037     NaN             NaN             NaN                      9.567890
# 4038     NaN             NaN             NaN                      9.567890
# 4039     NaN             NaN             NaN                      9.567890
# 4040     NaN             NaN             NaN                      9.567890
# 4041     NaN             NaN             NaN                      9.567890
# 4042     NaN             NaN             NaN                      9.602981
# 4043     NaN             NaN             NaN                      9.602981
# 4044     NaN             NaN             NaN                      9.602981
# 4045     NaN             NaN             NaN                      9.602981
# 4046     NaN             NaN             NaN                      9.602981
# 4047     NaN             NaN             NaN                      9.602981
# 4048     NaN             NaN             NaN                      9.602981
# 4049     NaN             NaN             NaN                      9.602981
# 4050     NaN             NaN             NaN                      9.602981
# 4051     NaN             NaN             NaN                      9.602981
# 4052     NaN             NaN             NaN                      9.602981
# 4053     NaN             NaN             NaN                      9.630952
# 4054     NaN             NaN             NaN                      9.630952
# 4055     NaN             NaN             NaN                      9.630952
# 4056     NaN             NaN             NaN                      9.630952
# 4057     NaN             NaN             NaN                      9.746772
# 4058     NaN             NaN             NaN                      9.746772
# 4059     NaN             NaN             NaN                      9.746772
#
#       EA Longitude (WGS84) Modified  Quantity_Kilograms
# 0                         37.890876               600.0
# 1                         37.890876               200.0
# 2                         37.890876               200.0
# 3                         37.890876                80.0
# 4                         37.890876               600.0
# 5                         37.890876               100.0
# 6                         37.890876               100.0
# 7                         37.890876               200.0
# 8                         37.890876                 8.0
# 9                         37.890876               200.0
# 10                        37.890876                10.0
# 11                        38.210252               170.0
# 12                        38.210252               260.0
# 13                        38.210252                 8.0
# 14                        38.210252               200.0
# 15                        38.210252                70.0
# 16                        38.210252                10.0
# 17                        38.210252               250.0
# 18                        38.210252               200.0
# 19                        38.210252                30.0
# 20                        38.210252                24.0
# 21                        38.210252                10.0
# 22                        38.210252               100.0
# 23                        38.473835                 2.0
# 24                        38.473835                 7.0
# 25                        38.480325                25.0
# 26                        38.480325                17.0
# 27                        38.480325               120.0
# 28                        38.480325                30.0
# 29                        38.480325               100.0
# ...                             ...                 ...
# 4030                      42.082365                 5.0
# 4031                      41.982267                40.0
# 4032                      41.982267                18.0
# 4033                      41.982267                 0.0
# 4034                      41.982267               132.0
# 4035                      41.982267                22.0
# 4036                      41.982267                93.0
# 4037                      41.982267                56.0
# 4038                      41.982267                24.0
# 4039                      41.982267                22.0
# 4040                      41.982267                40.0
# 4041                      41.982267                20.0
# 4042                      42.080329                25.0
# 4043                      42.080329                25.0
# 4044                      42.080329                 1.0
# 4045                      42.080329                 0.0
# 4046                      42.080329                 0.0
# 4047                      42.080329                50.0
# 4048                      42.080329                 9.0
# 4049                      42.080329                19.0
# 4050                      42.080329                28.0
# 4051                      42.080329                11.0
# 4052                      42.080329                19.0
# 4053                      42.146105                40.0
# 4054                      42.146105                25.0
# 4055                      42.146105                40.0
# 4056                      42.146105               400.0
# 4057                      42.308967               400.0
# 4058                      42.308967                 0.0
# 4059                      42.308967                40.0
#
# [4060 rows x 15 columns]

# %%
c_yields.shape
# Out:
# (4060, 15)

# %% [markdown]
# ### Land Area Lookups

# %%
if year == 2015:
    int_path = "Land Area Conversion Factor/"
    f = "ET_local_area_unit_conversion.dta"
elif year == 2013:
    int_path = ""
    f = "ET_local_area_unit_conversion.dta"
elif year == 2011:
    int_path = ""
    f = "ET_local_area_unit_conversion.dta"    

land_conversions = pd.read_stata(f'{LSMS_PATH}/{int_path}{f}')

# %% [markdown]
# Remove duplicates in land conversions dataframe:

# %%
land_conversions = land_conversions.drop_duplicates(subset=['region','zonename','woredaname'])

# %%
def gen_reg_zone_woreda(row, f):
    """
    Generates a string combining region_zone_woreda for use during lookups.
    """
    if f == 'c_yields':
        region = row['Region Code']
        zone = int(row['Zone Code'])
        woreda = int(row['Woreda Code'])
        return f"{region}_{zone}_{woreda}".lower()
    elif f == 'land_conversions':
        region = row['region']
        zone = int(row['zone'])
        woreda = int(row['woreda'])
        return f"{region}_{zone}_{woreda}".lower()

# %%
c_yields['region_zone_woreda'] = c_yields.apply(lambda row: gen_reg_zone_woreda(row, 'c_yields'), axis=1)

# %%
land_conversions['region_zone_woreda'] = land_conversions.apply(lambda row: gen_reg_zone_woreda(row, 'land_conversions'), axis=1)

# %%
c_yields.shape
# Out:
# (4060, 16)

# %%
c_yields = c_yields.merge(land_conversions, on='region_zone_woreda', how='left')

# %%
c_yields.shape
# Out:
# (4060, 23)

# %%
c_yields['Area_Normalized'] = c_yields['Area'] * c_yields['conversion']

# %% [markdown]
# ### Subset Crop Yields

# %%
c_yields_out = c_yields[['Unique HH ID in wave 2','region_zone_woreda','Crop Name','Quantity_Kilograms','EA Longitude (WGS84) Modified','EA Latitude (WGS84) Modified','Area_Normalized']]

# %%
out_vars = {'Unique HH ID in wave 2': 'Household_UUID',
            'zonename': 'Zone',
            'woredaname': 'Woreda',
            'Crop Name': 'Crop Name',
            'Quantity_Kilograms': 'Quantity (kg)',
            'EA Longitude (WGS84) Modified': 'Lon',
            'EA Latitude (WGS84) Modified': 'Lat',
            'Area_Normalized': 'Area (Normalized)'}

# %%
c_yields_out = c_yields_out.rename(columns=out_vars)
c_yields_out['Crop Name'] = c_yields_out['Crop Name'].apply(lambda x: str(x).title())

# %%
c_yields_out['Year'] = year

# %%
c_yields_out.to_csv(f'LSMS_{year}.csv', index=False)
